# %%
# mait/mait.ipynb(메인), result(출력 mp3), voice(입력 음성)

# %%
import os
import openai
import requests
import json
import playsound
from gtts import gTTS # gTTS install 필요

# voice to text
def voice2text(voiceFile, title):
    try:
        # API Endpoint
        url = "https://clovaspeech-gw.ncloud.com/recog/v1/stt"
        headers = {
            "X-CLOVASPEECH-API-KEY": "56f81be91e9344fd9825ff2dcb2b6d64", #콘솔 빌더의 비밀키
            "Content-Type": "application/octet-stream"
        }
        params = {
            "lang": "Kor"  # 언어 선택 (Kor, Eng, Jpn, Chn 중 선택)
        }

        # 음성 파일 입력
        # **확장자 확인**
        data = open(voiceFile, 'rb') # 음성 길이는 최대 60초(단문 인식)
        response = requests.post(url, headers=headers, params=params, data=data)
        rescode = response.status_code

        if(rescode == 200):
            result = response.json()
            text = result['text']
            print(f"입력: {text}")
            return text
        else:
            print("Error : " + response.text)
            return None
        
    except Exception as e:
        print(f"voice2text 실행 중 오류 발생: {str(e)}")
        return None

        
        
# text to voice
def text2voice(text, title):
    try:
        # TTS 객체 생성
        tts = gTTS(text=text, lang='ko')

        # mp3 파일로 저장
        tts.save("result/" + title + "_답변.mp3")
        print(f"출력: {text}")
        return True
        
    except Exception as e:
        print(f"text2voice 실행 중 오류 발생: {str(e)}")
        return False
    

def chatBot(title):
    try:
        voiceFile = "./voice/" + title + ".mp3"
        text = voice2text(voiceFile, title) # 음성 입력

        # OpenAI API 키 설정
        openai.api_key = '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'

        # 챗봇 세션 시작
        response = openai.ChatCompletion.create(
          model="gpt-3.5-turbo",  # 사용할 모델 설정
          messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": text},
            ]
        )

        r_text = response['choices'][0]['message']['content']
        text2voice(r_text, title)
        playsound.playsound(f"{title}.mp3")
        return True
        
    except Exception as e:
        print(f"챗봇 실행 중 오류 발생: {str(e)}")
        return False

    
    
if __name__ == '__main__':
    fileName = "직무" #확장자 제외 입력하기
    if chatBot(fileName):
        print(f"({fileName}) completed.")
    else:
        print(f"({fileName}) failed.")
# Out:
# 입력: 직무에 가장 필요한 역량은 무엇일까
# 출력: 직무에 가장 필요한 역량은 다양할 수 있지만 일반적으로는 다음과 같은 역량이 중요하게 여겨집니다.
#
# 1. 커뮤니케이션 능력: 명확하고 효과적인 커뮤니케이션 스킬은 업무를 원활하게 수행하는 데 매우 중요합니다.
# 2. 문제 해결 능력: 문제 상황에 직면했을 때 적절한 판단력과 분석 능력을 발휘하여 문제를 해결할 수 있는 능력이 필요합니다.
# 3. 리더십 능력: 팀을 이끄는 능력과 상황에 따라 적절한 리더십 스타일을 발휘할 수 있는 능력이 중요합니다.
# 4. 협업 능력: 효율적으로 팀원들과 협력하여 공동의 목표를 달성할 수 있는 능력이 필요합니다.
# 5. 적응성: 변화에 빠르게 적응하고 새로운 환경이나 상황에 유연하게 대처할 수 있는 능력이 중요합니다.
#
# 이 외에도 역량은 직무와 조직의 필요에 따라 달라질 수 있으니, 해당 직무에서 어떤 역량이 가장 중요한지 고려해 보시는 것이 좋습니다.
# (직무) completed.
